# %% [markdown]
# # Análise Exploratória

# %% [markdown]
# Teste explorando dados históricos

# %%
import pandas as pd
import pyarrow as pa

# %%
arquivo = "../data/raw/megasena/resultados.parquet.gzip"
df = pd.read_parquet(arquivo)

df.shape
# Out:
# (2549, 32)

# %%
df.head()
# Out:
#    acumulado dataApuracao dataProximoConcurso dezenasSorteadasOrdemSorteio  \
# 0       True   17/12/2022          31/12/2022     [30, 10, 33, 01, 06, 35]
# 1      False   14/12/2022          17/12/2022     [25, 23, 29, 30, 09, 15]
# 2       True   10/12/2022          14/12/2022     [37, 10, 38, 25, 31, 57]
# 3       True   07/12/2022          10/12/2022     [34, 03, 48, 28, 23, 38]
# 4       True   03/12/2022          07/12/2022     [57, 36, 32, 39, 20, 23]
#
#    exibirDetalhamentoPorCidade    id  indicadorConcursoEspecial  \
# 0                         True  None                          1
# 1                         True  None                          1
# 2                         True  None                          1
# 3                         True  None                          1
# 4                         True  None                          1
#
#                listaDezenas listaDezenasSegundoSorteio  \
# 0  [01, 06, 10, 30, 33, 35]                       None
# ...
